# %%
# %sql
SELECT current_catalog();

# %%
# %sql
CREATE CATALOG IF NOT EXISTS ottConsumption_catalog;

# %%
# %sql
-- USE CATALOG dbcks_demo_eus2_01_d;
-- CREATE DATABASE IF NOT EXISTS arijit_bronze_db;
-- USE arijit_bronze_db;

# %%
# %sql
-- DROP TABLE IF EXISTS dbcks_demo_eus2_01_d.arijit_bronze_db.watch_history;
-- DROP SCHEMA IF EXISTS arijit_bronze_db CASCADE;

# %%
# %sql
SHOW SCHEMAS;
CREATE SCHEMA IF NOT EXISTS dbcks_demo_eus2_01_d.arijit_raw_db;
CREATE SCHEMA IF NOT EXISTS dbcks_demo_eus2_01_d.arijit_bronze_db;
